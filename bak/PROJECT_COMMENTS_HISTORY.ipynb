# %%
import pandas as pd

# %%
table_name = 'PROJECT_COMMENTS_HISTORY'
PROJECT_COMMENTS_HISTORY = pd.read_csv(f"all_tables/{table_name}.csv")    
print(PROJECT_COMMENTS_HISTORY.shape[0])        
display(PROJECT_COMMENTS_HISTORY.tail(4))
# Out:
# 74220
#          UID  PROJECT_ID  COMMENTS_CATEGORY_L1_ID  COMMENTS_CATEGORY_L2_ID  \
# 74216  74705        1475                        1                       12
# 74217  74706        1475                        1                       13
# 74218  74707        1475                        1                       14
# 74219  74708        1475                        1                       15
#
#                                                 COMMENTS  PURPOSE  \
# 74216                                Nothing to report.       NaN
# 74217  - The completion date has been changed from 30...      NaN
# 74218  - Additional funds may require due to addition...      NaN
# 74219  - Please book the whole level 2 Building k fro...      NaN
#
#        CREATE_USER_ID              CREATE_DATE  MODIFY_USER_ID  MODIFY_DATE  \
# 74216             635  2019-08-09 14:06:28.197             NaN          NaN
# 74217             635  2019-08-09 14:06:28.213             NaN          NaN
# ...

# %%
PROJECT_COMMENTS_HISTORY[PROJECT_COMMENTS_HISTORY['UID']==51787]
# Out:
#          UID  PROJECT_ID  COMMENTS_CATEGORY_L1_ID  COMMENTS_CATEGORY_L2_ID  \
# 51298  51787         934                        1                        8
#
#                                                 COMMENTS  PURPOSE  \
# 51298  All works are now complete and mow in PC. \r\n...      NaN
#
#        CREATE_USER_ID              CREATE_DATE  MODIFY_USER_ID  MODIFY_DATE  \
# 51298             538  2018-05-30 14:20:37.777             NaN          NaN
#
#        SORT  ACTIVE
# 51298   NaN   False
