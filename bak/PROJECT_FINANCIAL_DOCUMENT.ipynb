# %%
import pandas as pd

# %%
table_name = 'RE_TENDER_EVALUATION_ACTUAL'
RE_TENDER_EVALUATION_ACTUAL = pd.read_csv(f"all_tables/{table_name}.csv")    
print(RE_TENDER_EVALUATION_ACTUAL.shape[0])        
display(RE_TENDER_EVALUATION_ACTUAL.tail(4))
# Out:
# 748
#      UID                 VendorName   VendorContact  \
# 744  745  Vincent Chrisp Architects      Jim Chrisp
# 745  746          Alchemy Construct  Jamie Nicolson
# 746  747            Baxter Projects    Morgan Cross
# 747  748              Kapitol Group  Andrew Deveson
#
#                      VenddorEmail  PR_UID  WorkPackageId  VendorId  \
# 744       jc@vincentchrisp.com.au    1477          51787       697
# 745   jamien@alchemyconstruct.com    1492          51826       682
# 746  morgan@baxterprojects.com.au    1492          51826       683
# 747  projects@kapitalgroup.com.au    1492          51826       684
#
#     VendorSubmission                                            DocPath  \
# 744              NaN  S:\FSD-Projects\18-External\1477 CL Multi Buil...
# 745              NaN  S:\FSD-Projects\02-Current\1492_CL 19 Penthous...
# 746              NaN  S:\FSD-Projects\02-Current\1492_CL 19 Penthous...
# ...

# %%
RE_TENDER_EVALUATION_ACTUAL[RE_TENDER_EVALUATION_ACTUAL['WorkPackageId']==51787]
# Out:
#      UID                 VendorName      VendorContact  \
# 742  743             JMA Architects        Nick Millar
# 743  744              NA Architects  Nicholas Daviotis
# 744  745  Vincent Chrisp Architects         Jim Chrisp
#
#                   VenddorEmail  PR_UID  WorkPackageId  VendorId  \
# 742  nickm@jmarchitects.com.au    1477          51787       695
# 743      naarch@bigpond.net.au    1477          51787       696
# 744    jc@vincentchrisp.com.au    1477          51787       697
#
#     VendorSubmission                                            DocPath  \
# 742              NaN  S:\FSD-Projects\18-External\1477 CL Multi Buil...
# 743              NaN  S:\FSD-Projects\18-External\1477 CL Multi Buil...
# 744              NaN  S:\FSD-Projects\18-External\1477 CL Multi Buil...
#
#      RawPrice  InitialRanking  NormalisedPrice  FinalRanking HighLevelComment  \
# 742  185500.0             2.0              NaN           NaN              NaN
# ...
