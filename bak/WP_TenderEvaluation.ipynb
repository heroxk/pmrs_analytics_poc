# %%
import pandas as pd

# %%
table_name = 'WP_TenderEvaluation'
WP_TenderEvaluation = pd.read_csv(f"all_tables/{table_name}.csv")    
print(WP_TenderEvaluation.shape[0])        
display(WP_TenderEvaluation.tail(4))
# Out:
# 748
#      VendorId  WorkPackageId VendorSubmission DocPath  RawPrice  \
# 744       760          52095              NaN     NaN       NaN
# 745       761          52095              NaN     NaN       NaN
# 746       762          52095              NaN     NaN       NaN
# 747       763          52095              NaN     NaN       NaN
#
#      InitialRanking  NormalisedPrice  FinalRanking HighLevelComment  \
# 744             NaN              NaN           NaN              NaN
# 745             NaN              NaN           NaN              NaN
# 746             NaN              NaN           NaN              NaN
# 747             NaN              NaN           NaN              NaN
#
#     IsClosedHighLevel EvaluationComment IsClosedEvaluation  VFM_Overall_Score
# 744               NaN               NaN                NaN                NaN
# 745               NaN               NaN                NaN                NaN
# 746               NaN               NaN                NaN                NaN
# 747               NaN               NaN                NaN                NaN

# %%
WP_TenderEvaluation[WP_TenderEvaluation['WorkPackageId']==51787]
# Out:
#      VendorId  WorkPackageId VendorSubmission  \
# 679       695          51787              NaN
# 680       696          51787              NaN
# 681       697          51787              NaN
#
#                                                DocPath  RawPrice  \
# 679  S:\FSD-Projects\18-External\1477 CL Multi Buil...  185500.0
# 680  S:\FSD-Projects\18-External\1477 CL Multi Buil...  130000.0
# 681  S:\FSD-Projects\18-External\1477 CL Multi Buil...  281000.0
#
#      InitialRanking  NormalisedPrice  FinalRanking HighLevelComment  \
# 679             2.0              NaN           NaN              NaN
# 680             1.0              NaN           NaN              NaN
# 681             3.0              NaN           NaN              NaN
#
#     IsClosedHighLevel EvaluationComment IsClosedEvaluation  VFM_Overall_Score
# 679               NaN               NaN                NaN                NaN
# 680               NaN               NaN                NaN                NaN
# 681               NaN               NaN                NaN                NaN
