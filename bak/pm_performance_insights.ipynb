# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import ks_2samp
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from pyod.models.abod import ABOD
from pyod.models.cblof import CBLOF
from pyod.models.feature_bagging import FeatureBagging
from pyod.models.hbos import HBOS
from pyod.models.iforest import IForest
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import matplotlib.font_manager
import dash

# %%
df = pd.read_excel("data/20191116_Misstarget_Abuse_Pattern.xlsx")

# %%
df.shape
# Out:
# (13469, 32)

# %%
selected_cols = [
    "MonthReport",
    "REF_UID",
    "PROJECT_NAME",
    "PM_NAME",
    "PD_NAME",
    "Forecast_Cash_Flow_Display",
    "Actual_Cash_Flow_Display",
    "Tolerances_Name"
]

# %%
df.columns
# Out:
# Index(['DATA_TYPE', 'MonthReport', 'REF_UID', 'PROJECT_NAME', 'PM_ID',
#        'PM_NAME', 'PD_ID', 'PD_NAME', 'BUDGET', 'Quarter',
#        'Forecast_Cash_Flow', 'Actual_Cash_Flow', 'Forecast_Cash_Flow_Display',
#        'Actual_Cash_Flow_Display', 'Variance_Display', 'Variance',
#        'Percentage', 'Percentage_Display', 'Color', 'Tolerance_Level',
#        'PC_Date', 'ClOSE_DATE', 'Tolerances_Name', 'Forecast_Cash_Flow_Total',
#        'Forecast_Cash_Flow_Total_Display', 'Actual_Cash_Flow_Total',
#        'Actual_Cash_Flow_Total_Display', 'Variance_Total',
#        'Variance_Total_Display', 'Percentage_Average',
#        'Percentage_Average_Display', 'TIMESTAMP'],
#       dtype='object')

# %%
df = df[selected_cols]

# %%
df.head()
# Out:
#   MonthReport  REF_UID                                     PROJECT_NAME  \
# 0     2017-07       83  Project Feasibility Assessments - Prior to 2015
# 1     2017-08       83  Project Feasibility Assessments - Prior to 2015
# 2     2017-09       83  Project Feasibility Assessments - Prior to 2015
# 3     2017-10       83  Project Feasibility Assessments - Prior to 2015
# 4     2017-11       83  Project Feasibility Assessments - Prior to 2015
#
#          PM_NAME        PD_NAME  Forecast_Cash_Flow_Display  \
# 0  Michael Scott  Nicole Collin                         0.0
# 1  Michael Scott  Program Admin                         0.0
# 2  Michael Scott  Program Admin                         0.0
# 3  Michael Scott  Program Admin                         0.0
# 4  Michael Scott  Program Admin                         0.0
#
#   Actual_Cash_Flow_Display Tolerances_Name
# 0                     5.46     Meet Target
# 1                    44.19     Meet Target
# 2                    17.02     Meet Target
# 3                     3.59     Meet Target
# 4                     4.13     Meet Target

# %% [markdown]
# ##### Remove Project with `Tolerances_Name` == `Not Applicable`

# %%
df = df[df['Tolerances_Name']!='Not Applicable']

# %% [markdown]
# ##### Remove Project with PD_NAME=Program Admin

# %%
df = df[df['PD_NAME']!='Program Admin']

# %% [markdown]
# ##### Remove Project with Forecast=0 and Actual=0

# %%
df = df[~((df['Forecast_Cash_Flow_Display']==0) & (df['Actual_Cash_Flow_Display']==0))]

# %% [markdown]
# ##### Remove PM in List

# %%
PM_remove = [
    'Carol Loh',
    'Loi Tran',
    'Axel Keert',
    'Program Admin',
    'Michael Scott',
    'Program Close',
    'Bradley Williamson',
    'Richard Feltscheer',
    'Tish Booth',
    'Stephen Lindsay',
    'David Baker',
    'Nethmi Dassanayake'
]
df = df[~df['PM_NAME'].isin(PM_remove)]

# %%
df[df['Forecast_Cash_Flow_Display']==0].shape
# Out:
# (730, 8)

# %% [markdown]
# ##### Remove SSAF Project with < 50K

# %%
name = 'Angus McGarvie'
# name = 'Jonathon Egan '
# df[df['PM_NAME']==name][df['Forecast_Cash_Flow_Display']==0][df['Actual_Cash_Flow_Display']>50].shape[0] /df[df['PM_NAME']==name].shape[0]

# %%
df[df['PM_NAME']==name][df['Forecast_Cash_Flow_Display']==0].shape
# Out:
# (124, 8)

# %%
df = df[~(df['PROJECT_NAME'].str.contains('SSAF') & (df['Actual_Cash_Flow_Display']<50) & (df['Forecast_Cash_Flow_Display']==0))]

# %% [markdown]
# ##### Remove Project ID = 1162

# %%
df = df[df['REF_UID']!=1162]

# %%
year_list = ['2016', '2017', '2018', '2019']
for year in year_list:
    print(f"{year}: {df[(df['MonthReport'].str.contains(year))].shape[0]}")
# Out:
# 2016: 1671
# 2017: 1687
# 2018: 1457
# 2019: 1144

# %%
# Exclude 2016 and 2017
df = \
df[(df['MonthReport'].str.contains('2018')) \
   | (df['MonthReport'].str.contains('2019')) 
  ]

# %%
print(f"Total Project in: {df.shape[0]}")
# Out:
# Total Project in: 2601

# %%
df_analytics = df.copy()

# %%
# df_analytics['Forecast_Variation'] = df_analytics['Forecast_Cash_Flow_Display'] - df_analytics['Actual_Cash_Flow_Display']
# df_analytics['Forecast_Variation_Perc'] = df_analytics['Forecast_Variation'] / (df_analytics['Actual_Cash_Flow_Display'] + 0.001)
# df_analytics['Forecast_Variation_Perc'] = df_analytics['Forecast_Variation_Perc'].astype('float')
df_analytics['Forecast_Cash_Flow_Display'] = df_analytics['Forecast_Cash_Flow_Display'].astype('float')
df_analytics['Actual_Cash_Flow_Display'] =  df_analytics['Actual_Cash_Flow_Display'].astype('float')

# %%
df_analytics.head(10)
# Out:
#    MonthReport  REF_UID                               PROJECT_NAME  \
# 36     2018-01      271             Matheson Library Refurbishment
# 37     2018-02      271             Matheson Library Refurbishment
# 38     2018-03      271             Matheson Library Refurbishment
# 39     2018-04      271             Matheson Library Refurbishment
# 40     2018-05      271             Matheson Library Refurbishment
# 41     2018-06      291  Biomedical Learning and Teaching Building
# 42     2018-07      291  Biomedical Learning and Teaching Building
# 43     2018-08      291  Biomedical Learning and Teaching Building
# 44     2018-09      291  Biomedical Learning and Teaching Building
# 45     2018-10      291  Biomedical Learning and Teaching Building
#
#                   PM_NAME             PD_NAME  Forecast_Cash_Flow_Display  \
# 36        Mark Soderlund     Kevin Weatherall                        6.29
# 37        Mark Soderlund     Kevin Weatherall                       43.80
# 38        Mark Soderlund     Kevin Weatherall                       15.55
# 39        Mark Soderlund     Kevin Weatherall                        0.00
# 40        Mark Soderlund     Kevin Weatherall                       23.56
# 41  Cristina De Pellegrin  Richard Feltscheer                     8651.09
# 42  Cristina De Pellegrin  Richard Feltscheer                     8527.16
# 43  Cristina De Pellegrin  Richard Feltscheer                     7548.07
# 44  Cristina De Pellegrin  Richard Feltscheer                     7806.35
# 45  Cristina De Pellegrin  Richard Feltscheer                     6018.61
#
#     Actual_Cash_Flow_Display Tolerances_Name
# 36                      6.29     Meet Target
# 37                     38.18        Critical
# 38                     32.21     Meet Target
# 39                      7.95     Meet Target
# 40                      6.09        Critical
# 41                   8480.29     Meet Target
# 42                   7833.03        Critical
# 43                   7273.06     Near Target
# 44                   7381.22        Critical
# 45                   7378.46     Meet Target

# %%
# PM_name = 'Angus McGarvie'
# PM_name = 'Dean Ristevski'
PM_name = 'Jeremy Chong'
df_person = df_analytics[df_analytics['PM_NAME']==PM_name]
# df_person[df_person['Forecast_Cash_Flow_Display']==0]
df_person.head(3)
# Out:
#      MonthReport  REF_UID                             PROJECT_NAME  \
# 1325     2019-04      792  CL 1 Doug Ellis Main Pool Remedial Work
# 1327     2019-06      792  CL 1 Doug Ellis Main Pool Remedial Work
# 1641     2018-02      842          Monash Sport Reception and Cafe
#
#            PM_NAME     PD_NAME  Forecast_Cash_Flow_Display  \
# 1325  Jeremy Chong  Axel Keert                        0.00
# 1327  Jeremy Chong  Axel Keert                        1.30
# 1641  Jeremy Chong  Axel Keert                       12.42
#
#       Actual_Cash_Flow_Display Tolerances_Name
# 1325                      1.61     Meet Target
# 1327                      0.00        Critical
# 1641                     12.42     Meet Target

# %%
underspend = df_person[(df_person['Forecast_Cash_Flow_Display'] - df_person['Actual_Cash_Flow_Display']) * 2 \
                    /(df_person['Actual_Cash_Flow_Display'] + df_person['Forecast_Cash_Flow_Display'])>0.05].shape[0]
print(f"underspend:{underspend}")
overderspend = df_person[(df_person['Actual_Cash_Flow_Display'] - df_person['Forecast_Cash_Flow_Display']) * 2 \
                    /(df_person['Actual_Cash_Flow_Display'] + df_person['Forecast_Cash_Flow_Display'])>0.05].shape[0]
print(f"overderspend:{overderspend}")
# Out:
# underspend:45
# overderspend:48

# %%
# df_person[(df_person['Forecast_Cash_Flow_Display'] - df_person['Actual_Cash_Flow_Display']) * 2 \
#                     /(df_person['Actual_Cash_Flow_Display'] + df_person['Forecast_Cash_Flow_Display'])>0.05]

# %%
df_0 = df[df['Forecast_Cash_Flow_Display']==0]
df_0.groupby(['PM_NAME']).count().sort_values('MonthReport',ascending=False)
# Out:
#                        MonthReport  REF_UID  PROJECT_NAME  PD_NAME  \
# PM_NAME
# Angus McGarvie                  89       89            89       89
# Jeremy Chong                    27       27            27       27
# Aarron Cowen                    21       21            21       21
# Nick Ditterich                  19       19            19       19
# Vivienne Elder-Smith            16       16            16       16
# Alexis Kouts                    16       16            16       16
# Jodie Katada                    15       15            15       15
# Hiruni Eriyagama                13       13            13       13
# Arash Emami                     13       13            13       13
# Jack Izowski                    12       12            12       12
# Jonathon Egan                   12       12            12       12
# Ron Too                         11       11            11       11
# Mark Bray                       11       11            11       11
# Ryan Martin                     10       10            10       10
# Dean Ristevski                  10       10            10       10
# Victor Oyanedel                  9        9             9        9
# Mark Soderlund                   9        9             9        9
# Bijins Joy                       8        8             8        8
# Rob Bacon                        8        8             8        8
# Yolande O'Mara                   7        7             7        7
# Eric Sun                         6        6             6        6
# Anna Devlin                      6        6             6        6
# James Creech                     5        5             5        5
# Ryan Spittel                     4        4             4        4
# Chris Thrasis                    4        4             4        4
# David Chauhan                    3        3             3        3
# Robert Dickson                   3        3             3        3
# Cristina De Pellegrin            3        3             3        3
# Gavin Zhang                      2        2             2        2
# Jean Low                         1        1             1        1
# Jacqueline Talevska              1        1             1        1
# Lincoln Stanley                  1        1             1        1
# David Tabatabaian                1        1             1        1
# David Baker                      1        1             1        1
#
#                        Forecast_Cash_Flow_Display  Actual_Cash_Flow_Display  \
# PM_NAME
# Angus McGarvie                                 89                        89
# Jeremy Chong                                   27                        27
# Aarron Cowen                                   21                        21
# Nick Ditterich                                 19                        19
# Vivienne Elder-Smith                           16                        16
# Alexis Kouts                                   16                        16
# Jodie Katada                                   15                        15
# Hiruni Eriyagama                               13                        13
# Arash Emami                                    13                        13
# Jack Izowski                                   12                        12
# Jonathon Egan                                  12                        12
# Ron Too                                        11                        11
# Mark Bray                                      11                        11
# Ryan Martin                                    10                        10
# Dean Ristevski                                 10                        10
# Victor Oyanedel                                 9                         9
# Mark Soderlund                                  9                         9
# Bijins Joy                                      8                         8
# Rob Bacon                                       8                         8
# Yolande O'Mara                                  7                         7
# Eric Sun                                        6                         6
# Anna Devlin                                     6                         6
# James Creech                                    5                         5
# Ryan Spittel                                    4                         4
# Chris Thrasis                                   4                         4
# David Chauhan                                   3                         3
# Robert Dickson                                  3                         3
# Cristina De Pellegrin                           3                         3
# Gavin Zhang                                     2                         2
# Jean Low                                        1                         1
# Jacqueline Talevska                             1                         1
# Lincoln Stanley                                 1                         1
# David Tabatabaian                               1                         1
# David Baker                                     1                         1
#
#                        Tolerances_Name
# PM_NAME
# Angus McGarvie                      89
# Jeremy Chong                        27
# Aarron Cowen                        21
# Nick Ditterich                      19
# Vivienne Elder-Smith                16
# Alexis Kouts                        16
# Jodie Katada                        15
# Hiruni Eriyagama                    13
# Arash Emami                         13
# Jack Izowski                        12
# Jonathon Egan                       12
# Ron Too                             11
# Mark Bray                           11
# Ryan Martin                         10
# Dean Ristevski                      10
# Victor Oyanedel                      9
# Mark Soderlund                       9
# Bijins Joy                           8
# Rob Bacon                            8
# Yolande O'Mara                       7
# Eric Sun                             6
# Anna Devlin                          6
# James Creech                         5
# Ryan Spittel                         4
# Chris Thrasis                        4
# David Chauhan                        3
# Robert Dickson                       3
# Cristina De Pellegrin                3
# Gavin Zhang                          2
# Jean Low                             1
# Jacqueline Talevska                  1
# Lincoln Stanley                      1
# David Tabatabaian                    1
# David Baker                          1

# %%
PM_list = list(set(df_analytics['PM_NAME']))

# %%
pm_perf = dict()

for name in PM_list:
#     if name != 'Angus McGarvie':
#     if name != 'Aarron Cowen':
#     if name != 'Matthew Bartlett':
#         continue

    df_tmp = df_analytics[df_analytics['PM_NAME']==name]
    mse = mean_squared_error(df_tmp['Actual_Cash_Flow_Display'], df_tmp['Forecast_Cash_Flow_Display']) / sum(df_tmp['Actual_Cash_Flow_Display'])
    
    # Metric: Project Delivered
    project_num = df_tmp.shape[0]
    
    # Metric: Total Project Value Delivered
    project_value = df_tmp['Actual_Cash_Flow_Display'].sum()
    project_value_inv = 1.0 / np.sqrt(project_value)
    
    # Metric: Number of Time that Put Forecast as Zero
    zero_fcst = df_tmp[df_tmp['Forecast_Cash_Flow_Display']==0].shape[0]
    
    # Metric KS Distribution
#     ks_distrb = ks_2samp(df_tmp['Forecast_Cash_Flow_Display'], df_tmp['Actual_Cash_Flow_Display'])
    
    # Metric: Total Number of Time that Missing Target
    underspend = df_tmp[(df_tmp['Forecast_Cash_Flow_Display'] - df_tmp['Actual_Cash_Flow_Display']) * 2 \
                        /(df_tmp['Actual_Cash_Flow_Display'] + df_tmp['Forecast_Cash_Flow_Display'])>0.05].shape[0]
                        
    overderspend = df_tmp[(df_tmp['Actual_Cash_Flow_Display'] - df_tmp['Forecast_Cash_Flow_Display']) * 2 \
                        /(df_tmp['Actual_Cash_Flow_Display'] + df_tmp['Forecast_Cash_Flow_Display'])>0.05].shape[0]
    
    underspend_project_num = underspend
    overspend_project_num = overderspend
   
    # Metric: Overspend/Underspend $
    df_tmp['spend_diff'] = df_tmp['Forecast_Cash_Flow_Display'] - df_tmp['Actual_Cash_Flow_Display']
    underspend_value = abs(sum(df_tmp[df_tmp['spend_diff']>0]['spend_diff']))                       
    overderspend_value = abs(sum(df_tmp[df_tmp['spend_diff']<0]['spend_diff']))  


    miss_target_project_num = underspend + overderspend

    # Metric: Percentage of Miss-target Project
    miss_target_project_ratio = miss_target_project_num / project_num

    
    # Metric: MAPE
    df_tmp.loc[:,'miss_taget_value_monthly_mape'] = abs(df_tmp['Forecast_Cash_Flow_Display'] - df_tmp['Actual_Cash_Flow_Display']) * 2 /\
                                           (df_tmp['Forecast_Cash_Flow_Display'] + df_tmp['Actual_Cash_Flow_Display'])
    
    miss_taget_value_monthly_mape = df_tmp['miss_taget_value_monthly_mape'].mean()
    
    # Metric: Total Missing Target $ Value (Can Cancel Off)
    miss_target_value = sum(df_tmp['Forecast_Cash_Flow_Display']) - sum(df_tmp['Actual_Cash_Flow_Display'])
    
    # Metric: Total Missing Target $ Value Percentage (Can Cancel Off)    
    miss_target_value_perc_error = abs(sum(df_tmp['Forecast_Cash_Flow_Display']) - sum(df_tmp['Actual_Cash_Flow_Display'])) * 2 / \
                                   (sum(df_tmp['Forecast_Cash_Flow_Display']) + sum(df_tmp['Actual_Cash_Flow_Display']))

    # Metric: Total Logged Missing Target Absolute $ Value (Can't Cancel Off)    
    miss_target_value_log_error = np.log(sum(abs((df_tmp['Forecast_Cash_Flow_Display']) - (df_tmp['Actual_Cash_Flow_Display']))))
    
    pm_perf[name] = [
        project_num,
        project_value,
        project_value_inv,
        zero_fcst,
#         ks_distrb,
        miss_taget_value_monthly_mape,
        miss_target_project_num,
        underspend_project_num,
        overspend_project_num,
        underspend_value,
        overderspend_value,
        miss_target_project_ratio,
        miss_target_value,
        miss_target_value_perc_error,
        miss_target_value_log_error
    ]

# %%
df_pm_perf = pd.DataFrame.from_dict(pm_perf, orient='index',
                                 columns=['project_num',
                                          'project_value',
                                          'project_value_inv',
                                          'zero_fcst',
#                                           'ks_distrb',
                                          'miss_taget_value_monthly_mape',
                                          'miss_target_project_num',
                                          'underspend_project_num',
                                          'overspend_project_num',
                                          'underspend_value',
                                          'overderspend_value',
                                          'miss_target_project_ratio',
                                          'miss_target_value',
                                          'miss_target_value_perc_error',
                                          'miss_target_value_log_error'
                                         ])

# %%
# Only track PMs who have delivered >10 project and total project value > $50K
df_pm_perf = df_pm_perf[(df_pm_perf['project_num']>=10) | (df_pm_perf['project_value']>=50)]

# %%
df_pm_perf.sort_values('miss_taget_value_monthly_mape').tail(3)
# Out:
#                 project_num  project_value  project_value_inv  zero_fcst  \
# Jodie Katada             35         891.81           0.033486         15
# Angus McGarvie          152        8884.76           0.010609         89
# Jarrod Filosa            16          40.94           0.156288          0
#
#                 miss_taget_value_monthly_mape  miss_target_project_num  \
# Jodie Katada                         1.581520                       33
# Angus McGarvie                       1.602316                      144
# Jarrod Filosa                        1.787894                       16
#
#                 underspend_project_num  overspend_project_num  \
# Jodie Katada                        16                     17
# Angus McGarvie                      32                    112
# Jarrod Filosa                       16                      0
#
#                 underspend_value  overderspend_value  \
# Jodie Katada              347.98              644.99
# Angus McGarvie            292.38             5855.76
# Jarrod Filosa             362.09                0.00
#
#                 miss_target_project_ratio  miss_target_value  \
# Jodie Katada                     0.942857            -297.01
# Angus McGarvie                   0.947368           -5563.38
# Jarrod Filosa                    1.000000             362.09
#
#                 miss_target_value_perc_error  miss_target_value_log_error
# Jodie Katada                        0.399580                     6.900700
# Angus McGarvie                      0.911571                     8.723905
# Jarrod Filosa                       1.631146                     5.891893

# %% [markdown]
# #### Good PM

# %%
df_pm_perf[(df_pm_perf.index=='Dean Ristevski') \
           | (df_pm_perf.index=='Jeremy Chong') \
           | (df_pm_perf.index=='Jonathon Egan ')\
           | (df_pm_perf.index=='Arash Emami')\
           | (df_pm_perf.index=='James Creech')\
           | (df_pm_perf.index=='Ryan Spittel')
          ]
# Out:
#                 project_num  project_value  project_value_inv  zero_fcst  \
# James Creech             77        6416.33           0.012484          5
# Dean Ristevski           65       13356.54           0.008653         10
# Arash Emami             128       19764.95           0.007113         13
# Ryan Spittel             63       40681.31           0.004958          4
# Jonathon Egan           319        9319.18           0.010359         12
# Jeremy Chong            120        5954.87           0.012959         27
#
#                 miss_taget_value_monthly_mape  miss_target_project_num  \
# James Creech                         0.949461                       57
# Dean Ristevski                       0.961929                       52
# Arash Emami                          0.716473                       84
# Ryan Spittel                         0.645170                       32
# Jonathon Egan                        1.268858                      267
# Jeremy Chong                         1.066846                       93
#
#                 underspend_project_num  overspend_project_num  \
# James Creech                        37                     20
# Dean Ristevski                      19                     33
# Arash Emami                         29                     55
# Ryan Spittel                        19                     13
# Jonathon Egan                      210                     57
# Jeremy Chong                        45                     48
#
#                 underspend_value  overderspend_value  \
# James Creech             1395.52              566.23
# Dean Ristevski            927.79             4097.60
# Arash Emami              3072.55             4891.34
# Ryan Spittel             3911.24             1761.48
# Jonathon Egan            1716.55             1886.06
# Jeremy Chong              865.61              560.61
#
#                 miss_target_project_ratio  miss_target_value  \
# James Creech                     0.740260             829.29
# Dean Ristevski                   0.800000           -3169.81
# Arash Emami                      0.656250           -1818.79
# Ryan Spittel                     0.507937            2149.76
# Jonathon Egan                    0.836991            -169.51
# Jeremy Chong                     0.775000             305.00
#
#                 miss_target_value_perc_error  miss_target_value_log_error
# James Creech                        0.121401                     7.581592
# Dean Ristevski                      0.269275                     8.522258
# Arash Emami                         0.096459                     8.982673
# Ryan Spittel                        0.051484                     8.643424
# Jonathon Egan                       0.018356                     8.189414
# Jeremy Chong                        0.049940                     7.262783

# %% [markdown]
# #### Bad PM

# %%
df_pm_perf[(df_pm_perf.index=='Angus McGarvie') \
           | (df_pm_perf.index=='Aarron Cowen') \
           | (df_pm_perf.index=='Eric Sun') \
           | (df_pm_perf.index=='Bijins Joy')           
          ]
# Out:
#                 project_num  project_value  project_value_inv  zero_fcst  \
# Bijins Joy               46        1020.19           0.031308          8
# Eric Sun                 30        9034.31           0.010521          6
# Aarron Cowen            140        8395.48           0.010914         21
# Angus McGarvie          152        8884.76           0.010609         89
#
#                 miss_taget_value_monthly_mape  miss_target_project_num  \
# Bijins Joy                           0.757145                       32
# Eric Sun                             0.972625                       26
# Aarron Cowen                         1.137502                      132
# Angus McGarvie                       1.602316                      144
#
#                 underspend_project_num  overspend_project_num  \
# Bijins Joy                           9                     23
# Eric Sun                            10                     16
# Aarron Cowen                        70                     62
# Angus McGarvie                      32                    112
#
#                 underspend_value  overderspend_value  \
# Bijins Joy                 38.02              255.90
# Eric Sun                 2318.91             3585.22
# Aarron Cowen             2531.54             1756.24
# Angus McGarvie            292.38             5855.76
#
#                 miss_target_project_ratio  miss_target_value  \
# Bijins Joy                       0.695652            -217.88
# Eric Sun                         0.866667           -1266.31
# Aarron Cowen                     0.942857             775.30
# Angus McGarvie                   0.947368           -5563.38
#
#                 miss_target_value_perc_error  miss_target_value_log_error
# Bijins Joy                          0.239100                     5.683308
# Eric Sun                            0.150730                     8.683407
# Aarron Cowen                        0.088271                     8.363524
# Angus McGarvie                      0.911571                     8.723905

# %%
df_pm_perf.sort_values('miss_target_value_perc_error')
# Out:
#                        project_num  project_value  project_value_inv  \
# Mark Barrett                     4         351.26           0.053356
# Jonathon Egan                  319        9319.18           0.010359
# Ryan Martin                     43        2450.63           0.020200
# Hiruni Eriyagama                97        6706.35           0.012211
# Cristina De Pellegrin           41      101884.34           0.003133
# Alexis Kouts                    79      105390.88           0.003080
# Jeremy Chong                   120        5954.87           0.012959
# Ryan Spittel                    63       40681.31           0.004958
# Jacqueline Talevska             23       13763.16           0.008524
# Jack Izowski                    78        6845.71           0.012086
# Yolande O'Mara                  47        2551.76           0.019796
# Nick Ditterich                  99       17328.40           0.007597
# Aarron Cowen                   140        8395.48           0.010914
# Rob Bacon                       23        2642.59           0.019453
# Arash Emami                    128       19764.95           0.007113
# Adel Mousa                       7         240.00           0.064550
# Robert Dickson                  14        1402.31           0.026704
# James Creech                    77        6416.33           0.012484
# Eric Sun                        30        9034.31           0.010521
# David Tabatabaian                5          50.86           0.140221
# Kiryll Sirant                   28        3425.99           0.017085
# Victor Oyanedel                122       59268.41           0.004108
# Ron Too                        174        8324.26           0.010960
# Bijins Joy                      46        1020.19           0.031308
# Rebal Fakhreddine               22         462.64           0.046492
# Dean Ristevski                  65       13356.54           0.008653
# Mark Soderlund                 111        8924.58           0.010585
# Chris Webster                    7        2898.60           0.018574
# Chris Thrasis                   45        1497.84           0.025838
# David Chauhan                   72        5940.88           0.012974
# Jodie Katada                    35         891.81           0.033486
# Jean Low                        11          98.97           0.100519
# Gavin Zhang                     14         552.39           0.042548
# Vivienne Elder-Smith           149        4584.55           0.014769
# Mark Bray                       38        3251.17           0.017538
# Anna Devlin                     32        1104.92           0.030084
# David Baker                      5         133.56           0.086529
# Daniel Bartel                   14         966.36           0.032168
# Angus McGarvie                 152        8884.76           0.010609
# Jarrod Filosa                   16          40.94           0.156288
#
#                        zero_fcst  miss_taget_value_monthly_mape  \
# Mark Barrett                   0                       0.615225
# Jonathon Egan                 12                       1.268858
# Ryan Martin                   10                       0.935929
# Hiruni Eriyagama              13                       1.070321
# Cristina De Pellegrin          3                       0.803350
# Alexis Kouts                  16                       0.971761
# Jeremy Chong                  27                       1.066846
# Ryan Spittel                   4                       0.645170
# Jacqueline Talevska            1                       0.812424
# Jack Izowski                  12                       1.156784
# Yolande O'Mara                 7                       0.721040
# Nick Ditterich                19                       1.118978
# Aarron Cowen                  21                       1.137502
# Rob Bacon                      8                       0.932541
# Arash Emami                   13                       0.716473
# Adel Mousa                     0                       0.774788
# Robert Dickson                 3                       1.375616
# James Creech                   5                       0.949461
# Eric Sun                       6                       0.972625
# David Tabatabaian              1                       0.602268
# Kiryll Sirant                  0                       0.757346
# Victor Oyanedel                9                       0.896589
# Ron Too                       11                       1.100246
# Bijins Joy                     8                       0.757145
# Rebal Fakhreddine              0                       0.997796
# Dean Ristevski                10                       0.961929
# Mark Soderlund                 9                       0.943985
# Chris Webster                  0                       0.770221
# Chris Thrasis                  4                       1.364661
# David Chauhan                  3                       1.111737
# Jodie Katada                  15                       1.581520
# Jean Low                       1                       0.829974
# Gavin Zhang                    2                       0.971496
# Vivienne Elder-Smith          16                       1.124077
# Mark Bray                     11                       0.979925
# Anna Devlin                    6                       1.290785
# David Baker                    1                       1.151759
# Daniel Bartel                  0                       0.797948
# Angus McGarvie                89                       1.602316
# Jarrod Filosa                  0                       1.787894
#
#                        miss_target_project_num  underspend_project_num  \
# Mark Barrett                                 4                       2
# Jonathon Egan                              267                     210
# Ryan Martin                                 31                      16
# Hiruni Eriyagama                            83                      43
# Cristina De Pellegrin                       35                      23
# Alexis Kouts                                62                      36
# Jeremy Chong                                93                      45
# Ryan Spittel                                32                      19
# Jacqueline Talevska                         16                      12
# Jack Izowski                                70                      34
# Yolande O'Mara                              39                      20
# Nick Ditterich                              89                      49
# Aarron Cowen                               132                      70
# Rob Bacon                                   14                       4
# Arash Emami                                 84                      29
# Adel Mousa                                   4                       3
# Robert Dickson                              14                       7
# James Creech                                57                      37
# Eric Sun                                    26                      10
# David Tabatabaian                            3                       2
# Kiryll Sirant                               24                      17
# Victor Oyanedel                            108                      75
# Ron Too                                    150                     100
# Bijins Joy                                  32                       9
# Rebal Fakhreddine                           21                      15
# Dean Ristevski                              52                      19
# Mark Soderlund                              97                      52
# Chris Webster                                7                       3
# Chris Thrasis                               43                      34
# David Chauhan                               65                      51
# Jodie Katada                                33                      16
# Jean Low                                    11                       8
# Gavin Zhang                                 11                       7
# Vivienne Elder-Smith                       129                      90
# Mark Bray                                   27                       7
# Anna Devlin                                 32                      22
# David Baker                                  4                       2
# Daniel Bartel                               11                      10
# Angus McGarvie                             144                      32
# Jarrod Filosa                               16                      16
#
#                        overspend_project_num  underspend_value  \
# Mark Barrett                               2             82.84
# Jonathon Egan                             57           1716.55
# Ryan Martin                               15            365.92
# Hiruni Eriyagama                          40           1858.09
# Cristina De Pellegrin                     12          13423.61
# Alexis Kouts                              26           5977.42
# Jeremy Chong                              48            865.61
# Ryan Spittel                              13           3911.24
# Jacqueline Talevska                        4           1420.97
# Jack Izowski                              36           2047.72
# Yolande O'Mara                            19            367.78
# Nick Ditterich                            40           3732.55
# Aarron Cowen                              62           2531.54
# Rob Bacon                                 10             52.93
# Arash Emami                               55           3072.55
# Adel Mousa                                 1             33.70
# Robert Dickson                             7            400.44
# James Creech                              20           1395.52
# Eric Sun                                  16           2318.91
# David Tabatabaian                          1             20.22
# Kiryll Sirant                              7            790.25
# Victor Oyanedel                           33          16019.32
# Ron Too                                   50           3774.22
# Bijins Joy                                23             38.02
# Rebal Fakhreddine                          6            216.08
# Dean Ristevski                            33            927.79
# Mark Soderlund                            45           1207.60
# Chris Webster                              4           1674.64
# Chris Thrasis                              9            770.67
# David Chauhan                             14           3708.42
# Jodie Katada                              17            347.98
# Jean Low                                   3             56.52
# Gavin Zhang                                4            354.87
# Vivienne Elder-Smith                      39           4569.63
# Mark Bray                                 20            280.33
# Anna Devlin                               10           1224.94
# David Baker                                2            150.69
# Daniel Bartel                              1            945.29
# Angus McGarvie                           112            292.38
# Jarrod Filosa                              0            362.09
#
#                        overderspend_value  miss_target_project_ratio  \
# Mark Barrett                        80.08                   1.000000
# Jonathon Egan                     1886.06                   0.836991
# Ryan Martin                        279.50                   0.720930
# Hiruni Eriyagama                  2094.21                   0.855670
# Cristina De Pellegrin             9340.21                   0.853659
# Alexis Kouts                      1631.25                   0.784810
# Jeremy Chong                       560.61                   0.775000
# Ryan Spittel                      1761.48                   0.507937
# Jacqueline Talevska                601.66                   0.695652
# Jack Izowski                      2454.33                   0.897436
# Yolande O'Mara                     531.88                   0.829787
# Nick Ditterich                    4890.81                   0.898990
# Aarron Cowen                      1756.24                   0.942857
# Rob Bacon                          288.87                   0.608696
# Arash Emami                       4891.34                   0.656250
# Adel Mousa                           6.61                   0.571429
# Robert Dickson                     234.08                   1.000000
# James Creech                       566.23                   0.740260
# Eric Sun                          3585.22                   0.866667
# David Tabatabaian                   11.00                   0.600000
# Kiryll Sirant                      167.80                   0.857143
# Victor Oyanedel                   4108.98                   0.885246
# Ron Too                           1577.86                   0.862069
# Bijins Joy                         255.90                   0.695652
# Rebal Fakhreddine                   75.94                   0.954545
# Dean Ristevski                    4097.60                   0.800000
# Mark Soderlund                    3342.96                   0.873874
# Chris Webster                      698.61                   1.000000
# Chris Thrasis                      210.57                   0.955556
# David Chauhan                      957.96                   0.902778
# Jodie Katada                       644.99                   0.942857
# Jean Low                             5.64                   1.000000
# Gavin Zhang                         15.82                   0.785714
# Vivienne Elder-Smith              1307.27                   0.865772
# Mark Bray                         1655.00                   0.710526
# Anna Devlin                        408.78                   1.000000
# David Baker                         34.32                   0.800000
# Daniel Bartel                       24.66                   0.785714
# Angus McGarvie                    5855.76                   0.947368
# Jarrod Filosa                        0.00                   1.000000
#
#                        miss_target_value  miss_target_value_perc_error  \
# Mark Barrett                        2.76                      0.007827
# Jonathon Egan                    -169.51                      0.018356
# Ryan Martin                        86.42                      0.034653
# Hiruni Eriyagama                 -236.12                      0.035839
# Cristina De Pellegrin            4083.40                      0.039291
# Alexis Kouts                     4346.17                      0.040405
# Jeremy Chong                      305.00                      0.049940
# Ryan Spittel                     2149.76                      0.051484
# Jacqueline Talevska               819.31                      0.057809
# Jack Izowski                     -406.61                      0.061214
# Yolande O'Mara                   -164.10                      0.066445
# Nick Ditterich                  -1158.26                      0.069153
# Aarron Cowen                      775.30                      0.088271
# Rob Bacon                        -235.94                      0.093456
# Arash Emami                     -1818.79                      0.096459
# Adel Mousa                         27.09                      0.106845
# Robert Dickson                    166.36                      0.111990
# James Creech                      829.29                      0.121401
# Eric Sun                        -1266.31                      0.150730
# David Tabatabaian                   9.22                      0.166216
# Kiryll Sirant                     622.45                      0.166555
# Victor Oyanedel                 11910.34                      0.182608
# Ron Too                          2196.36                      0.233099
# Bijins Joy                       -217.88                      0.239100
# Rebal Fakhreddine                 140.14                      0.263070
# Dean Ristevski                  -3169.81                      0.269275
# Mark Soderlund                  -2135.36                      0.271781
# Chris Webster                     976.03                      0.288202
# Chris Thrasis                     560.10                      0.315036
# David Chauhan                    2750.46                      0.375946
# Jodie Katada                     -297.01                      0.399580
# Jean Low                           50.88                      0.408970
# Gavin Zhang                       339.05                      0.469654
# Vivienne Elder-Smith             3262.36                      0.524855
# Mark Bray                       -1374.67                      0.536177
# Anna Devlin                       816.16                      0.539432
# David Baker                       116.37                      0.606900
# Daniel Bartel                     920.63                      0.645298
# Angus McGarvie                  -5563.38                      0.911571
# Jarrod Filosa                     362.09                      1.631146
#
#                        miss_target_value_log_error
# Mark Barrett                              5.093259
# Jonathon Egan                             8.189414
# Ryan Martin                               6.469901
# Hiruni Eriyagama                          8.282053
# Cristina De Pellegrin                    10.032928
# Alexis Kouts                              8.937044
# Jeremy Chong                              7.262783
# Ryan Spittel                              8.643424
# Jacqueline Talevska                       7.612154
# Jack Izowski                              8.412288
# Yolande O'Mara                            6.802017
# Nick Ditterich                            9.062230
# Aarron Cowen                              8.363524
# Rob Bacon                                 5.834226
# Arash Emami                               8.982673
# Adel Mousa                                3.696600
# Robert Dickson                            6.452869
# James Creech                              7.581592
# Eric Sun                                  8.683407
# David Tabatabaian                         3.441059
# Kiryll Sirant                             6.864900
# Victor Oyanedel                           9.909882
# Ron Too                                   8.585241
# Bijins Joy                                5.683308
# Rebal Fakhreddine                         5.676822
# Dean Ristevski                            8.522258
# Mark Soderlund                            8.423006
# Chris Webster                             7.772016
# Chris Thrasis                             6.888817
# David Chauhan                             8.448139
# Jodie Katada                              6.900700
# Jean Low                                  4.129712
# Gavin Zhang                               5.915366
# Vivienne Elder-Smith                      8.678785
# Mark Bray                                 7.568033
# Anna Devlin                               7.398615
# David Baker                               5.220410
# Daniel Bartel                             6.877245
# Angus McGarvie                            8.723905
# Jarrod Filosa                             5.891893

# %%
col_list = [
    'zero_fcst',
    'project_value_inv',
    'miss_taget_value_monthly_mape',  
    'miss_target_project_ratio',
#     'miss_target_value',
    'miss_target_value_perc_error',
#     'miss_target_value_log_error'
]

df_pm_perf_select = df_pm_perf[col_list].dropna()

# %%
df_pm_perf_select.head(3)
# Out:
#                 zero_fcst  project_value_inv  miss_taget_value_monthly_mape  \
# Chris Thrasis           4           0.025838                       1.364661
# Jodie Katada           15           0.033486                       1.581520
# Yolande O'Mara          7           0.019796                       0.721040
#
#                 miss_target_project_ratio  miss_target_value_perc_error
# Chris Thrasis                    0.955556                      0.315036
# Jodie Katada                     0.942857                      0.399580
# Yolande O'Mara                   0.829787                      0.066445

# %%
for col in col_list:
    df_pm_perf_select[col] = df_pm_perf_select[col] / df_pm_perf_select[col].max()

# %%
data = df_pm_perf_select[col_list].as_matrix()

# %%
top_n_outlier = 20
num_PM = len(PM_list)
outliers_fraction = top_n_outlier * 1.0 / num_PM

# %%
select_metrics= [
    'miss_taget_value_monthly_mape',
    'project_value_inv',
    'project_value_inv',
    'miss_target_project_ratio',
    'miss_target_value_perc_error',
    'miss_target_value_perc_error',
    'miss_target_value_perc_error',
    'miss_target_value_perc_error',
    'miss_target_value_perc_error',
    'miss_target_value_perc_error',
    'miss_target_value_perc_error',
    'miss_target_value_perc_error',
#     'miss_target_value',
#     'miss_target_value_log_error'
]

# %%
df_pm_perf_select[select_metrics]
# Out:
#                        miss_taget_value_monthly_mape  project_value_inv  \
# Chris Thrasis                               0.763279           0.165326
# Jodie Katada                                0.884571           0.214258
# Yolande O'Mara                              0.403290           0.126664
# Rob Bacon                                   0.521586           0.124468
# Daniel Bartel                               0.446306           0.205828
# James Creech                                0.531050           0.079879
# Bijins Joy                                  0.423484           0.200324
# Robert Dickson                              0.769406           0.170865
# Jarrod Filosa                               1.000000           1.000000
# Ryan Martin                                 0.523481           0.129251
# Mark Barrett                                0.344106           0.341397
# Mark Soderlund                              0.527987           0.067730
# Dean Ristevski                              0.538023           0.055364
# Rebal Fakhreddine                           0.558084           0.297476
# Kiryll Sirant                               0.423597           0.109315
# Vivienne Elder-Smith                        0.628716           0.094499
# Gavin Zhang                                 0.543374           0.272239
# Arash Emami                                 0.400735           0.045512
# Nick Ditterich                              0.625863           0.048607
# Anna Devlin                                 0.721958           0.192490
# David Chauhan                               0.621814           0.083013
# Chris Webster                               0.430798           0.118845
# Eric Sun                                    0.544006           0.067317
# Ryan Spittel                                0.360854           0.031723
# Mark Bray                                   0.548089           0.112216
# Jonathon Egan                               0.709694           0.066280
# Hiruni Eriyagama                            0.598649           0.078132
# Jeremy Chong                                0.596705           0.082916
# Aarron Cowen                                0.636225           0.069831
# David Tabatabaian                           0.336859           0.897193
# Jacqueline Talevska                         0.454403           0.054540
# Alexis Kouts                                0.543522           0.019709
# Victor Oyanedel                             0.501478           0.026282
# Angus McGarvie                              0.896203           0.067881
# Jack Izowski                                0.647009           0.077333
# Adel Mousa                                  0.433352           0.413017
# Cristina De Pellegrin                       0.449328           0.020046
# David Baker                                 0.644198           0.553651
# Jean Low                                    0.464219           0.643165
# Ron Too                                     0.615386           0.070130
#
#                        project_value_inv  miss_target_project_ratio  \
# Chris Thrasis                   0.165326                   0.955556
# Jodie Katada                    0.214258                   0.942857
# Yolande O'Mara                  0.126664                   0.829787
# Rob Bacon                       0.124468                   0.608696
# Daniel Bartel                   0.205828                   0.785714
# James Creech                    0.079879                   0.740260
# Bijins Joy                      0.200324                   0.695652
# Robert Dickson                  0.170865                   1.000000
# Jarrod Filosa                   1.000000                   1.000000
# Ryan Martin                     0.129251                   0.720930
# Mark Barrett                    0.341397                   1.000000
# Mark Soderlund                  0.067730                   0.873874
# Dean Ristevski                  0.055364                   0.800000
# Rebal Fakhreddine               0.297476                   0.954545
# Kiryll Sirant                   0.109315                   0.857143
# Vivienne Elder-Smith            0.094499                   0.865772
# Gavin Zhang                     0.272239                   0.785714
# Arash Emami                     0.045512                   0.656250
# Nick Ditterich                  0.048607                   0.898990
# Anna Devlin                     0.192490                   1.000000
# David Chauhan                   0.083013                   0.902778
# Chris Webster                   0.118845                   1.000000
# Eric Sun                        0.067317                   0.866667
# Ryan Spittel                    0.031723                   0.507937
# Mark Bray                       0.112216                   0.710526
# Jonathon Egan                   0.066280                   0.836991
# Hiruni Eriyagama                0.078132                   0.855670
# Jeremy Chong                    0.082916                   0.775000
# Aarron Cowen                    0.069831                   0.942857
# David Tabatabaian               0.897193                   0.600000
# Jacqueline Talevska             0.054540                   0.695652
# Alexis Kouts                    0.019709                   0.784810
# Victor Oyanedel                 0.026282                   0.885246
# Angus McGarvie                  0.067881                   0.947368
# Jack Izowski                    0.077333                   0.897436
# Adel Mousa                      0.413017                   0.571429
# Cristina De Pellegrin           0.020046                   0.853659
# David Baker                     0.553651                   0.800000
# Jean Low                        0.643165                   1.000000
# Ron Too                         0.070130                   0.862069
#
#                        miss_target_value_perc_error  \
# Chris Thrasis                              0.193138
# Jodie Katada                               0.244969
# Yolande O'Mara                             0.040735
# Rob Bacon                                  0.057294
# Daniel Bartel                              0.395610
# James Creech                               0.074427
# Bijins Joy                                 0.146584
# Robert Dickson                             0.068657
# Jarrod Filosa                              1.000000
# Ryan Martin                                0.021245
# Mark Barrett                               0.004798
# Mark Soderlund                             0.166620
# Dean Ristevski                             0.165083
# Rebal Fakhreddine                          0.161279
# Kiryll Sirant                              0.102109
# Vivienne Elder-Smith                       0.321771
# Gavin Zhang                                0.287929
# Arash Emami                                0.059136
# Nick Ditterich                             0.042395
# Anna Devlin                                0.330707
# David Chauhan                              0.230479
# Chris Webster                              0.176687
# Eric Sun                                   0.092408
# Ryan Spittel                               0.031563
# Mark Bray                                  0.328712
# Jonathon Egan                              0.011254
# Hiruni Eriyagama                           0.021972
# Jeremy Chong                               0.030616
# Aarron Cowen                               0.054116
# David Tabatabaian                          0.101901
# Jacqueline Talevska                        0.035440
# Alexis Kouts                               0.024771
# Victor Oyanedel                            0.111951
# Angus McGarvie                             0.558853
# Jack Izowski                               0.037528
# Adel Mousa                                 0.065503
# Cristina De Pellegrin                      0.024088
# David Baker                                0.372070
# Jean Low                                   0.250726
# Ron Too                                    0.142905
#
#                        miss_target_value_perc_error  \
# Chris Thrasis                              0.193138
# Jodie Katada                               0.244969
# Yolande O'Mara                             0.040735
# Rob Bacon                                  0.057294
# Daniel Bartel                              0.395610
# James Creech                               0.074427
# Bijins Joy                                 0.146584
# Robert Dickson                             0.068657
# Jarrod Filosa                              1.000000
# Ryan Martin                                0.021245
# Mark Barrett                               0.004798
# Mark Soderlund                             0.166620
# Dean Ristevski                             0.165083
# Rebal Fakhreddine                          0.161279
# Kiryll Sirant                              0.102109
# Vivienne Elder-Smith                       0.321771
# Gavin Zhang                                0.287929
# Arash Emami                                0.059136
# Nick Ditterich                             0.042395
# Anna Devlin                                0.330707
# David Chauhan                              0.230479
# Chris Webster                              0.176687
# Eric Sun                                   0.092408
# Ryan Spittel                               0.031563
# Mark Bray                                  0.328712
# Jonathon Egan                              0.011254
# Hiruni Eriyagama                           0.021972
# Jeremy Chong                               0.030616
# Aarron Cowen                               0.054116
# David Tabatabaian                          0.101901
# Jacqueline Talevska                        0.035440
# Alexis Kouts                               0.024771
# Victor Oyanedel                            0.111951
# Angus McGarvie                             0.558853
# Jack Izowski                               0.037528
# Adel Mousa                                 0.065503
# Cristina De Pellegrin                      0.024088
# David Baker                                0.372070
# Jean Low                                   0.250726
# Ron Too                                    0.142905
#
#                        miss_target_value_perc_error  \
# Chris Thrasis                              0.193138
# Jodie Katada                               0.244969
# Yolande O'Mara                             0.040735
# Rob Bacon                                  0.057294
# Daniel Bartel                              0.395610
# James Creech                               0.074427
# Bijins Joy                                 0.146584
# Robert Dickson                             0.068657
# Jarrod Filosa                              1.000000
# Ryan Martin                                0.021245
# Mark Barrett                               0.004798
# Mark Soderlund                             0.166620
# Dean Ristevski                             0.165083
# Rebal Fakhreddine                          0.161279
# Kiryll Sirant                              0.102109
# Vivienne Elder-Smith                       0.321771
# Gavin Zhang                                0.287929
# Arash Emami                                0.059136
# Nick Ditterich                             0.042395
# Anna Devlin                                0.330707
# David Chauhan                              0.230479
# Chris Webster                              0.176687
# Eric Sun                                   0.092408
# Ryan Spittel                               0.031563
# Mark Bray                                  0.328712
# Jonathon Egan                              0.011254
# Hiruni Eriyagama                           0.021972
# Jeremy Chong                               0.030616
# Aarron Cowen                               0.054116
# David Tabatabaian                          0.101901
# Jacqueline Talevska                        0.035440
# Alexis Kouts                               0.024771
# Victor Oyanedel                            0.111951
# Angus McGarvie                             0.558853
# Jack Izowski                               0.037528
# Adel Mousa                                 0.065503
# Cristina De Pellegrin                      0.024088
# David Baker                                0.372070
# Jean Low                                   0.250726
# Ron Too                                    0.142905
#
#                        miss_target_value_perc_error  \
# Chris Thrasis                              0.193138
# Jodie Katada                               0.244969
# Yolande O'Mara                             0.040735
# Rob Bacon                                  0.057294
# Daniel Bartel                              0.395610
# James Creech                               0.074427
# Bijins Joy                                 0.146584
# Robert Dickson                             0.068657
# Jarrod Filosa                              1.000000
# Ryan Martin                                0.021245
# Mark Barrett                               0.004798
# Mark Soderlund                             0.166620
# Dean Ristevski                             0.165083
# Rebal Fakhreddine                          0.161279
# Kiryll Sirant                              0.102109
# Vivienne Elder-Smith                       0.321771
# Gavin Zhang                                0.287929
# Arash Emami                                0.059136
# Nick Ditterich                             0.042395
# Anna Devlin                                0.330707
# David Chauhan                              0.230479
# Chris Webster                              0.176687
# Eric Sun                                   0.092408
# Ryan Spittel                               0.031563
# Mark Bray                                  0.328712
# Jonathon Egan                              0.011254
# Hiruni Eriyagama                           0.021972
# Jeremy Chong                               0.030616
# Aarron Cowen                               0.054116
# David Tabatabaian                          0.101901
# Jacqueline Talevska                        0.035440
# Alexis Kouts                               0.024771
# Victor Oyanedel                            0.111951
# Angus McGarvie                             0.558853
# Jack Izowski                               0.037528
# Adel Mousa                                 0.065503
# Cristina De Pellegrin                      0.024088
# David Baker                                0.372070
# Jean Low                                   0.250726
# Ron Too                                    0.142905
#
#                        miss_target_value_perc_error  \
# Chris Thrasis                              0.193138
# Jodie Katada                               0.244969
# Yolande O'Mara                             0.040735
# Rob Bacon                                  0.057294
# Daniel Bartel                              0.395610
# James Creech                               0.074427
# Bijins Joy                                 0.146584
# Robert Dickson                             0.068657
# Jarrod Filosa                              1.000000
# Ryan Martin                                0.021245
# Mark Barrett                               0.004798
# Mark Soderlund                             0.166620
# Dean Ristevski                             0.165083
# Rebal Fakhreddine                          0.161279
# Kiryll Sirant                              0.102109
# Vivienne Elder-Smith                       0.321771
# Gavin Zhang                                0.287929
# Arash Emami                                0.059136
# Nick Ditterich                             0.042395
# Anna Devlin                                0.330707
# David Chauhan                              0.230479
# Chris Webster                              0.176687
# Eric Sun                                   0.092408
# Ryan Spittel                               0.031563
# Mark Bray                                  0.328712
# Jonathon Egan                              0.011254
# Hiruni Eriyagama                           0.021972
# Jeremy Chong                               0.030616
# Aarron Cowen                               0.054116
# David Tabatabaian                          0.101901
# Jacqueline Talevska                        0.035440
# Alexis Kouts                               0.024771
# Victor Oyanedel                            0.111951
# Angus McGarvie                             0.558853
# Jack Izowski                               0.037528
# Adel Mousa                                 0.065503
# Cristina De Pellegrin                      0.024088
# David Baker                                0.372070
# Jean Low                                   0.250726
# Ron Too                                    0.142905
#
#                        miss_target_value_perc_error  \
# Chris Thrasis                              0.193138
# Jodie Katada                               0.244969
# Yolande O'Mara                             0.040735
# Rob Bacon                                  0.057294
# Daniel Bartel                              0.395610
# James Creech                               0.074427
# Bijins Joy                                 0.146584
# Robert Dickson                             0.068657
# Jarrod Filosa                              1.000000
# Ryan Martin                                0.021245
# Mark Barrett                               0.004798
# Mark Soderlund                             0.166620
# Dean Ristevski                             0.165083
# Rebal Fakhreddine                          0.161279
# Kiryll Sirant                              0.102109
# Vivienne Elder-Smith                       0.321771
# Gavin Zhang                                0.287929
# Arash Emami                                0.059136
# Nick Ditterich                             0.042395
# Anna Devlin                                0.330707
# David Chauhan                              0.230479
# Chris Webster                              0.176687
# Eric Sun                                   0.092408
# Ryan Spittel                               0.031563
# Mark Bray                                  0.328712
# Jonathon Egan                              0.011254
# Hiruni Eriyagama                           0.021972
# Jeremy Chong                               0.030616
# Aarron Cowen                               0.054116
# David Tabatabaian                          0.101901
# Jacqueline Talevska                        0.035440
# Alexis Kouts                               0.024771
# Victor Oyanedel                            0.111951
# Angus McGarvie                             0.558853
# Jack Izowski                               0.037528
# Adel Mousa                                 0.065503
# Cristina De Pellegrin                      0.024088
# David Baker                                0.372070
# Jean Low                                   0.250726
# Ron Too                                    0.142905
#
#                        miss_target_value_perc_error  \
# Chris Thrasis                              0.193138
# Jodie Katada                               0.244969
# Yolande O'Mara                             0.040735
# Rob Bacon                                  0.057294
# Daniel Bartel                              0.395610
# James Creech                               0.074427
# Bijins Joy                                 0.146584
# Robert Dickson                             0.068657
# Jarrod Filosa                              1.000000
# Ryan Martin                                0.021245
# Mark Barrett                               0.004798
# Mark Soderlund                             0.166620
# Dean Ristevski                             0.165083
# Rebal Fakhreddine                          0.161279
# Kiryll Sirant                              0.102109
# Vivienne Elder-Smith                       0.321771
# Gavin Zhang                                0.287929
# Arash Emami                                0.059136
# Nick Ditterich                             0.042395
# Anna Devlin                                0.330707
# David Chauhan                              0.230479
# Chris Webster                              0.176687
# Eric Sun                                   0.092408
# Ryan Spittel                               0.031563
# Mark Bray                                  0.328712
# Jonathon Egan                              0.011254
# Hiruni Eriyagama                           0.021972
# Jeremy Chong                               0.030616
# Aarron Cowen                               0.054116
# David Tabatabaian                          0.101901
# Jacqueline Talevska                        0.035440
# Alexis Kouts                               0.024771
# Victor Oyanedel                            0.111951
# Angus McGarvie                             0.558853
# Jack Izowski                               0.037528
# Adel Mousa                                 0.065503
# Cristina De Pellegrin                      0.024088
# David Baker                                0.372070
# Jean Low                                   0.250726
# Ron Too                                    0.142905
#
#                        miss_target_value_perc_error
# Chris Thrasis                              0.193138
# Jodie Katada                               0.244969
# Yolande O'Mara                             0.040735
# Rob Bacon                                  0.057294
# Daniel Bartel                              0.395610
# James Creech                               0.074427
# Bijins Joy                                 0.146584
# Robert Dickson                             0.068657
# Jarrod Filosa                              1.000000
# Ryan Martin                                0.021245
# Mark Barrett                               0.004798
# Mark Soderlund                             0.166620
# Dean Ristevski                             0.165083
# Rebal Fakhreddine                          0.161279
# Kiryll Sirant                              0.102109
# Vivienne Elder-Smith                       0.321771
# Gavin Zhang                                0.287929
# Arash Emami                                0.059136
# Nick Ditterich                             0.042395
# Anna Devlin                                0.330707
# David Chauhan                              0.230479
# Chris Webster                              0.176687
# Eric Sun                                   0.092408
# Ryan Spittel                               0.031563
# Mark Bray                                  0.328712
# Jonathon Egan                              0.011254
# Hiruni Eriyagama                           0.021972
# Jeremy Chong                               0.030616
# Aarron Cowen                               0.054116
# David Tabatabaian                          0.101901
# Jacqueline Talevska                        0.035440
# Alexis Kouts                               0.024771
# Victor Oyanedel                            0.111951
# Angus McGarvie                             0.558853
# Jack Izowski                               0.037528
# Adel Mousa                                 0.065503
# Cristina De Pellegrin                      0.024088
# David Baker                                0.372070
# Jean Low                                   0.250726
# Ron Too                                    0.142905

# %%
df_pm_perf_select['pm_performance_score[abs]'] = 1 - df_pm_perf_select.apply(lambda x: np.linalg.norm(x[select_metrics]), axis=1)/np.sqrt(len(select_metrics))

# %%
print(f"Median Score: {df_pm_perf_select['pm_performance_score[abs]'].median():.02f}")
# Out:
# Median Score: 0.68

# %%
df_pm_perf_select.sort_values('pm_performance_score[abs]', ascending=False).tail(20)
# Out:
#                       zero_fcst  project_value_inv  \
# Mark Soderlund         0.101124           0.067730
# Ron Too                0.123596           0.070130
# Aarron Cowen           0.235955           0.069831
# Mark Barrett           0.000000           0.341397
# Chris Webster          0.000000           0.118845
# Rebal Fakhreddine      0.000000           0.297476
# David Chauhan          0.033708           0.083013
# Robert Dickson         0.033708           0.170865
# Mark Bray              0.123596           0.112216
# Gavin Zhang            0.022472           0.272239
# Chris Thrasis          0.044944           0.165326
# Vivienne Elder-Smith   0.179775           0.094499
# Daniel Bartel          0.000000           0.205828
# David Tabatabaian      0.011236           0.897193
# Jodie Katada           0.168539           0.214258
# Anna Devlin            0.067416           0.192490
# Jean Low               0.011236           0.643165
# David Baker            0.011236           0.553651
# Angus McGarvie         1.000000           0.067881
# Jarrod Filosa          0.000000           1.000000
#
#                       miss_taget_value_monthly_mape  \
# Mark Soderlund                             0.527987
# Ron Too                                    0.615386
# Aarron Cowen                               0.636225
# Mark Barrett                               0.344106
# Chris Webster                              0.430798
# Rebal Fakhreddine                          0.558084
# David Chauhan                              0.621814
# Robert Dickson                             0.769406
# Mark Bray                                  0.548089
# Gavin Zhang                                0.543374
# Chris Thrasis                              0.763279
# Vivienne Elder-Smith                       0.628716
# Daniel Bartel                              0.446306
# David Tabatabaian                          0.336859
# Jodie Katada                               0.884571
# Anna Devlin                                0.721958
# Jean Low                                   0.464219
# David Baker                                0.644198
# Angus McGarvie                             0.896203
# Jarrod Filosa                              1.000000
#
#                       miss_target_project_ratio  miss_target_value_perc_error  \
# Mark Soderlund                         0.873874                      0.166620
# Ron Too                                0.862069                      0.142905
# Aarron Cowen                           0.942857                      0.054116
# Mark Barrett                           1.000000                      0.004798
# Chris Webster                          1.000000                      0.176687
# Rebal Fakhreddine                      0.954545                      0.161279
# David Chauhan                          0.902778                      0.230479
# Robert Dickson                         1.000000                      0.068657
# Mark Bray                              0.710526                      0.328712
# Gavin Zhang                            0.785714                      0.287929
# Chris Thrasis                          0.955556                      0.193138
# Vivienne Elder-Smith                   0.865772                      0.321771
# Daniel Bartel                          0.785714                      0.395610
# David Tabatabaian                      0.600000                      0.101901
# Jodie Katada                           0.942857                      0.244969
# Anna Devlin                            1.000000                      0.330707
# Jean Low                               1.000000                      0.250726
# David Baker                            0.800000                      0.372070
# Angus McGarvie                         0.947368                      0.558853
# Jarrod Filosa                          1.000000                      1.000000
#
#                       pm_performance_score[abs]
# Mark Soderlund                         0.674206
# Ron Too                                0.671484
# Aarron Cowen                           0.667466
# Mark Barrett                           0.664379
# Chris Webster                          0.650765
# Rebal Fakhreddine                      0.633975
# David Chauhan                          0.630269
# Robert Dickson                         0.624935
# Mark Bray                              0.624185
# Gavin Zhang                            0.620960
# Chris Thrasis                          0.607491
# Vivienne Elder-Smith                   0.592672
# Daniel Bartel                          0.576392
# David Tabatabaian                      0.575103
# Jodie Katada                           0.567629
# Anna Devlin                            0.546287
# Jean Low                               0.539409
# David Baker                            0.519069
# Angus McGarvie                         0.407798
# Jarrod Filosa                          0.000000

# %%
df_pm_perf_select[(df_pm_perf_select.index=='Dean Ristevski') \
           | (df_pm_perf_select.index=='Jeremy Chong') \
           | (df_pm_perf_select.index=='Jonathon Egan ')\
           | (df_pm_perf_select.index=='Arash Emami')\
           | (df_pm_perf_select.index=='James Creech')\
           | (df_pm_perf_select.index=='Ryan Spittel')
          ]
# Out:
#                 zero_fcst  project_value_inv  miss_taget_value_monthly_mape  \
# James Creech     0.056180           0.079879                       0.531050
# Dean Ristevski   0.112360           0.055364                       0.538023
# Arash Emami      0.146067           0.045512                       0.400735
# Ryan Spittel     0.044944           0.031723                       0.360854
# Jonathon Egan    0.134831           0.066280                       0.709694
# Jeremy Chong     0.303371           0.082916                       0.596705
#
#                 miss_target_project_ratio  miss_target_value_perc_error  \
# James Creech                     0.740260                      0.074427
# Dean Ristevski                   0.800000                      0.165083
# Arash Emami                      0.656250                      0.059136
# Ryan Spittel                     0.507937                      0.031563
# Jonathon Egan                    0.836991                      0.011254
# Jeremy Chong                     0.775000                      0.030616
#
#                 pm_performance_score[abs]
# James Creech                     0.728112
# Dean Ristevski                   0.689944
# Arash Emami                      0.772080
# Ryan Spittel                     0.817838
# Jonathon Egan                    0.681931
# Jeremy Chong                     0.714528

# %%
df_pm_perf_select[(df_pm_perf_select.index=='Angus McGarvie') \
           | (df_pm_perf_select.index=='Aarron Cowen') \
           | (df_pm_perf_select.index=='Eric Sun') \
           | (df_pm_perf_select.index=='Bijins Joy')           
          ]
# Out:
#                 zero_fcst  project_value_inv  miss_taget_value_monthly_mape  \
# Bijins Joy       0.089888           0.200324                       0.423484
# Eric Sun         0.067416           0.067317                       0.544006
# Aarron Cowen     0.235955           0.069831                       0.636225
# Angus McGarvie   1.000000           0.067881                       0.896203
#
#                 miss_target_project_ratio  miss_target_value_perc_error  \
# Bijins Joy                       0.695652                      0.146584
# Eric Sun                         0.866667                      0.092408
# Aarron Cowen                     0.942857                      0.054116
# Angus McGarvie                   0.947368                      0.558853
#
#                 pm_performance_score[abs]
# Bijins Joy                       0.723802
# Eric Sun                         0.693891
# Aarron Cowen                     0.667466
# Angus McGarvie                   0.407798

# %%
classifiers = {
#         'Angle-based Outlier Detector (ABOD)': ABOD(contamination=outliers_fraction),
#         'Cluster-based Local Outlier Factor (CBLOF)':CBLOF(contamination=outliers_fraction,check_estimator=False, random_state=42),
#         'Feature Bagging':FeatureBagging(LOF(n_neighbors=35),contamination=outliers_fraction,check_estimator=False,random_state=42),
#         'Histogram-base Outlier Detection (HBOS)': HBOS(contamination=outliers_fraction),
#         'Isolation Forest': IForest(contamination=outliers_fraction,random_state=42),
        'K Nearest Neighbors (KNN)': KNN(contamination=outliers_fraction),
#         'Average KNN': KNN(method='mean',contamination=outliers_fraction)
}

# %%
col_list = ['pm_performance_score[abs]', 'zero_fcst']

for col in col_list:
    df_pm_perf_select[col] = df_pm_perf_select[col] / df_pm_perf_select[col].max()

# %%
top_n_outlier = 8

X_train = df_pm_perf_select[col_list].as_matrix()

# %%
high_perf_boundry = 1

# %%
#set the figure size

fig = plt.figure(figsize=(32, 16))

xx , yy = np.meshgrid(np.linspace(0, 1, num_PM), np.linspace(0, 1, num_PM))

for i, (clf_name,clf) in enumerate(classifiers.items()) :
    # fit the dataset to the model
    clf.fit(X_train)

    # predict raw anomaly score
    scores_pred = clf.decision_function(X_train)*-1

    # prediction of a datapoint category outlier or inlier
    y_pred = clf.predict(X_train)
    y_pred_proba = clf.predict_proba(X_train)
    threshold = np.percentile(y_pred_proba[:,0], 20)
    y_pred = np.where(y_pred_proba[:,0]>threshold, 0, 1)
    
    df_pm_perf_select['outlier'] = y_pred
    
    perf_median = np.median(df_pm_perf_select[df_pm_perf_select['outlier']!=1]['pm_performance_score[abs]'].values)
    perf_70pt = np.percentile(df_pm_perf_select['pm_performance_score[abs]'],70)
    high_perf_boundry = perf_70pt
    # rest of the code is to create the visualization

    # threshold value to consider a datapoint inlier or outlier
    threshold = stats.scoreatpercentile(scores_pred, top_n_outlier)

#     # decision function calculates the raw anomaly score for every point
    Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()]) * -1
    Z = Z.reshape(xx.shape)

    subplot = plt.subplot(1, 2, i + 1)

    # fill blue colormap from minimum anomaly score to threshold value
    subplot.contourf(xx, yy, Z, levels = np.linspace(Z.min(), threshold+0.02, 5),cmap=plt.cm.Blues_r)

#     # draw red contour line where anomaly score is equal to threshold
    a = subplot.contour(xx, yy, Z, levels=[threshold+0.12],linewidths=1, colors='red')

#     # fill orange contour lines where range of anomaly score is from threshold to maximum anomaly score
#     subplot.contourf(xx, yy, Z, levels=[threshold+0.02, Z.max()],colors='orange')

    # scatter plot of inliers with white dots
#     b = subplot.scatter(X_train[:-n_outliers, 0], X_train[:-n_outliers, 1], c='white',s=20, edgecolor='k') 

    df_pm_perf_select_ok = df_pm_perf_select[df_pm_perf_select['outlier']==0]
    df_pm_perf_select_under = df_pm_perf_select[df_pm_perf_select['outlier']==1]

    inlier = subplot.scatter(df_pm_perf_select_ok[col_list[0]], df_pm_perf_select_ok[col_list[1]], c='#99EE90',s=40, edgecolor='k') 
    outlier = subplot.scatter(df_pm_perf_select_under[col_list[0]], df_pm_perf_select_under[col_list[1]], c='red',s=60, edgecolor='k')
    subplot.axis('tight')

    subplot.legend(
#         [a.collections[0], inlier, outlier],
#         ['Performance Boundary', 'PM (Average)', 'PM (Outlier)'],
        [inlier, outlier],
        ['PM (Average)', 'PM (Outlier)'],
        prop=matplotlib.font_manager.FontProperties(size=10),
        loc='higher right')

    subplot.set_title("PM Performance Insights Dashboard", fontsize='xx-large')
    x_axis_max = df_pm_perf_select[col_list[0]].max()*1.1
    x_axis_min = min(df_pm_perf_select[col_list[0]].min()*1.1, -0.1)
    y_axis_max = df_pm_perf_select[col_list[1]].max()*1.1
    y_axis_min = min(df_pm_perf_select[col_list[1]].min()*1.1, -0.1)
    plt.axvspan(high_perf_boundry, 1, ymin = 0.08, ymax = 0.45, facecolor='#0DEF42', alpha=0.5)
    
    subplot.set_xlim((x_axis_min, x_axis_max))
    subplot.set_ylim((y_axis_min, y_axis_max))
    subplot.set_xlabel("Combined KPI Score (High the Better)", fontsize='x-large')
    subplot.set_ylabel("Non-Realistic Forecast", fontsize='x-large')
    for index, row in df_pm_perf_select.iterrows():

        label = index
        x = row[col_list[0]]
        y = row[col_list[1]]
        
        if row['outlier']==0:
            continue
            
#         if label != 'Angus McGarvie':
#             continue
            
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,3), # distance from text to points (x,y)
                     ha='center') # horizontal alignment can be left, right or center
    plt.savefig('./output/pm_performance_dashboard.pdf')
    plt.show()

# %%
df_pm_perf_select[df_pm_perf_select['outlier']==1]
# Out:
#                       zero_fcst  project_value_inv  \
# Jodie Katada           0.168539           0.214258
# Jarrod Filosa          0.000000           1.000000
# Vivienne Elder-Smith   0.179775           0.094499
# Arash Emami            0.146067           0.045512
# Ryan Spittel           0.044944           0.031723
# Jeremy Chong           0.303371           0.082916
# Aarron Cowen           0.235955           0.069831
# Angus McGarvie         1.000000           0.067881
#
#                       miss_taget_value_monthly_mape  \
# Jodie Katada                               0.884571
# Jarrod Filosa                              1.000000
# Vivienne Elder-Smith                       0.628716
# Arash Emami                                0.400735
# Ryan Spittel                               0.360854
# Jeremy Chong                               0.596705
# Aarron Cowen                               0.636225
# Angus McGarvie                             0.896203
#
#                       miss_target_project_ratio  miss_target_value_perc_error  \
# Jodie Katada                           0.942857                      0.244969
# Jarrod Filosa                          1.000000                      1.000000
# Vivienne Elder-Smith                   0.865772                      0.321771
# Arash Emami                            0.656250                      0.059136
# Ryan Spittel                           0.507937                      0.031563
# Jeremy Chong                           0.775000                      0.030616
# Aarron Cowen                           0.942857                      0.054116
# Angus McGarvie                         0.947368                      0.558853
#
#                       pm_performance_score[abs]  outlier
# Jodie Katada                           0.694061        1
# Jarrod Filosa                          0.000000        1
# Vivienne Elder-Smith                   0.724681        1
# Arash Emami                            0.944050        1
# Ryan Spittel                           1.000000        1
# Jeremy Chong                           0.873680        1
# Aarron Cowen                           0.816136        1
# Angus McGarvie                         0.498630        1

# %%
df_pm_perf_select[['zero_fcst', 'pm_performance_score[abs]', 'outlier']].reset_index().rename(columns={'index':'pm'}).to_csv('./data/pm_perf.csv', index=False)

# %%
pd.read_csv('data/pm_perf.csv').head(3)
# Out:
#                pm  zero_fcst  pm_performance_score[abs]  outlier
# 0   Chris Thrasis   0.044944                   0.742801        0
# 1    Jodie Katada   0.168539                   0.694061        1
# 2  Yolande O'Mara   0.078652                   0.888518        0

# %%
# df_angus['Forecast_Cash_Flow_Display'].plot(figsize=(24,16))
# df_angus['Actual_Cash_Flow_Display'].plot(figsize=(24,16))

# %%
# agg_cond = [
#     'PM_NAME',
# ]
# target = ['Forecast_Variation_Perc']
# selected_cols = agg_cond + target
# agg_ops = [
#     'mean'
# ]
# agg_target = target[0] + '_' + agg_ops[0]
# df_agg = df_analytics[selected_cols].groupby(agg_cond).agg(agg_ops)

# df_agg.columns = ['_'.join(col).strip(' ') for col in df_agg.columns.values]
# df_agg = df_agg.reset_index()

# df_agg.sort_values(agg_target, ascending=False)

# %%
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
np.random.seed(42)
random_x = np.random.randint(1,101,100)
random_y = np.random.randint(1,101,100)

df = pd.read_csv('data/pm_perf.csv')

data = [go.Scatter(x=[high_perf_boundry, high_perf_boundry, 1, 1], y=[0, 0.5, 0.5, 0],
                    fill='toself', fillcolor='rgba(135, 206, 250, 0.2)',
                    name="High Performance Area",
                    hoverinfo='text+x+y')]

data = \
data + ([go.Scatter(x=df[df['outlier']==0]['pm_performance_score[abs]'],
                   y=df[df['outlier']==0]['zero_fcst'],
                   text = df[df['outlier']==0]['pm'],
                   mode='markers',
                   name = "PM (Average)",
                   marker=dict(
                     size=8,
                     color='rgb(51,204,153)',
                     symbol='circle',
                     line={'width':2}
                   ))])

data = \
data + ([go.Scatter(x=df[df['outlier']==1]['pm_performance_score[abs]'],
                   y=df[df['outlier']==1]['zero_fcst'],
                   text = df[df['outlier']==1]['pm'],
                   mode='markers',
                   name = "PM (Outlier)",
                   marker=dict(
                     size=8,
                     color='red',
                     symbol='circle',
                     line={'width':2}
                   ))])

layout = go.Layout(title='PM Performance Insights Dashboard',
                   xaxis=dict(title='Combined KPI Score (High the Better)'),
                   yaxis=dict(title='Non-Realistic Forecast'),
                   hovermode='closest')

fig = go.Figure(data=data,layout=layout)

pyo.plot(fig, filename='pm_perf_dashboard_interactive.html')
# Out:
# 'pm_perf_dashboard_interactive.html'

# %%
df_pm_perf_vis = df_pm_perf[['underspend_value', 'overderspend_value', 'miss_target_project_ratio']].merge(df_pm_perf_select['outlier'], how='inner', left_index=True, right_index =True)

# %%
df_pm_perf_vis['underspend_value'] = df_pm_perf_vis['underspend_value'].astype('int')
df_pm_perf_vis['overderspend_value'] = df_pm_perf_vis['overderspend_value'].astype('int')
df_pm_perf_vis['miss_target_project_ratio'] = df_pm_perf_vis['miss_target_project_ratio']*100
df_pm_perf_vis['miss_target_project_ratio'] = df_pm_perf_vis['miss_target_project_ratio'].astype('int')

# %%
df_pm_perf_vis = df_pm_perf_vis.reset_index().rename(columns={'index':'pm'})

# %%
# import plotly.express as px
# iris = px.data.iris()
# fig = px.scatter_3d(df_pm_perf_vis, 
#                     x='underspend_value', 
#                     y='overderspend_value', 
#                     z='miss_target_project_ratio',
#                     color='outlier'
#                    )
# fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
# pyo.plot(fig, filename='pm_spending_dashboard_interactive.html')

# %%
data=[go.Scatter3d(
    x=df_pm_perf_vis[df_pm_perf_vis['outlier']==0]['underspend_value'],
    y=df_pm_perf_vis[df_pm_perf_vis['outlier']==0]['overderspend_value'],
    z=df_pm_perf_vis[df_pm_perf_vis['outlier']==0]['miss_target_project_ratio'],
    name = "PM (Average)",
    mode='markers',
    text=df_pm_perf_vis[df_pm_perf_vis['outlier']==0]['pm'],
    marker=dict(
        size=5,
#         color=df_pm_perf_vis['outlier'],                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)]

data = \
data + ([go.Scatter3d(
    x=df_pm_perf_vis[df_pm_perf_vis['outlier']==1]['underspend_value'],
    y=df_pm_perf_vis[df_pm_perf_vis['outlier']==1]['overderspend_value'],
    z=df_pm_perf_vis[df_pm_perf_vis['outlier']==1]['miss_target_project_ratio'],
    mode='markers',
    name = "PM (Outlier)",
    text=df_pm_perf_vis[df_pm_perf_vis['outlier']==1]['pm'],
    marker=dict(
        size=8,
#         color=df_pm_perf_vis['outlier'],                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)])

layout = go.Layout(title='PM Project Spending Dashboard',
                   scene = dict(
                    xaxis_title='X: Underspending Total Value (K$)',
                    yaxis_title='Y: Overspeningd Total Value (K$)',
                    zaxis_title='Z: Ratio of Miss-Target Projects (%)'),
                   width=1400,
#                    xaxis=dict(title='Combined KPI Score (High the Better)'),
#                    yaxis=dict(title='Non-Realistic Forecast'),
#                    zaxis=dict(title='Non-Realistic Forecast'),
                   hovermode='closest')

fig = go.Figure(data=data,layout=layout)
pyo.plot(fig, filename='pm_spending_dashboard_interactive.html')
# Out:
# 'pm_spending_dashboard_interactive.html'
